# %% [markdown]
# <a href="https://colab.research.google.com/github/Moon-xm/Bi-LSTM-CRF-NER-pytorch/blob/master/colab_run_result.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/Shareddrives/xm/Bi-LSTM-CRF-NER-pytorch
# Out:
# /content/drive/Shareddrives/xm/Bi-LSTM-CRF-NER-pytorch

# %% [markdown]
# 普通的BiLSTM_CRF(来自pytorch官网）速度慢，且在电脑cpu运行比colab上运行快的多（1倍）

# %%
# !python3 run.py
# Out:
# Loading data...
#
# Vocab size: 4769
# 2220537it [00:02, 990281.27it/s]
# 177232it [00:00, 902140.76it/s]
# Loading model...
# Model(
#   (embedding): Embedding(4769, 300)
#   (rnn): LSTM(300, 300, num_layers=2, batch_first=True, bidirectional=True)
#   (hidden2tag): Linear(in_features=600, out_features=9, bias=True)
# )
# Training and evaluating on cuda:0...
# Epoch [1/40]
# Iter:    100, Train loss: 5.8e+01, Train acc: 90.62%, dev loss: 9.3e+01, dev acc: 88.43%, Time: 0:07:20 *
# Iter:    200, Train loss: 6.4e+01, Train acc: 87.50%, dev loss: 8.8e+01, dev acc: 88.05%, Time: 0:14:39
# Traceback (most recent call last):
#   File "/content/drive/Shareddrives/xm/Bi-LSTM-CRF-NER-pytorch/train_eval.py", line 82, in evaluate
#     score, predict = model(x)  # forward
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
# ...

# %% [markdown]
# BiLSTM_faster（速度快）batch_size = 64, 128, 512速度差不太多

# %%
# !pip install git+https://github.com/yumoh/torchcrf.git
# Out:
# ...
#   Cloning https://github.com/yumoh/torchcrf.git to /tmp/pip-req-build-go9a_0t5
#   Running command git clone -q https://github.com/yumoh/torchcrf.git /tmp/pip-req-build-go9a_0t5
# ...
#   Created wheel for torchcrf: filename=torchcrf-0.0.1-cp36-none-any.whl size=4782 sha256=83b96994336c526c646d313c1ede49a8e22c2a217344fe233c333bc43678737e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-s8cqyutk/wheels/55/37/e1/bbeef1e2a0acd9ac8fe95e84722af94d29c17dd95135911fe2
# Successfully built torchcrf
# ...
#   Found existing installation: TorchCRF 1.1.0
#     Uninstalling TorchCRF-1.1.0:
#       Successfully uninstalled TorchCRF-1.1.0
# ...

# %%
# !python3 run.py
# Out:
# Loading data...
# Vocab size: 4769
# 2220537it [00:02, 941948.03it/s]
# 177232it [00:00, 849247.35it/s]
# Loading model...
# Model(
#   (embedding): Embedding(4769, 300)
#   (rnn): LSTM(300, 300, num_layers=2, batch_first=True, bidirectional=True)
#   (hidden2tag): Linear(in_features=600, out_features=9, bias=True)
#   (crf): CRF(num_tags=9)
# )
# Training and evaluating on cuda:0...
# Load epoch 3 successful...
# Epoch [4/20]
# /usr/local/lib/python3.6/dist-packages/torchcrf/__init__.py:112: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   mask = torch.tensor(self._new(tags.size()).fill_(1)).byte()
# Iter:    100, Train loss: 5.5e+01, Train acc: 88.28%, dev loss: 4.5e+01, dev acc: 89.80%, Time: 0:00:39
# Iter:    200, Train loss: 3.5e+01, Train acc: 90.62%, dev loss: 4.4e+01, dev acc: 90.20%, Time: 0:01:18 *
# ...

# %%
import pickle
vocab = pickle.load(open('/content/drive/Shareddrives/xm/Bi-LSTM-CRF-NER-pytorch/data/vocab.pkl','rb'))
print(vocab)
# Out:
# {'，': 0, '的': 1, '。': 2, '国': 3, '一': 4, '、': 5, '在': 6, '中': 7, '了': 8, '是': 9, '人': 10, '和': 11, '有': 12, '大': 13, '1': 14, '不': 15, '年': 16, '0': 17, '为': 18, '会': 19, '这': 20, '”': 21, '“': 22, '上': 23, '发': 24, '个': 25, '地': 26, '业': 27, '作': 28, '学': 29, '出': 30, '2': 31, '家': 32, '日': 33, '行': 34, '以': 35, '对': 36, '生': 37, '要': 38, '到': 39, '来': 40, '经': 41, '9': 42, '多': 43, '成': 44, '工': 45, '时': 46, '们': 47, '他': 48, '部': 49, '进': 50, '我': 51, '市': 52, '民': 53, '于': 54, '本': 55, '全': 56, '5': 57, '理': 58, '政': 59, '新': 60, '下': 61, '主': 62, '长': 63, '实': 64, '展': 65, '3': 66, '方': 67, '现': 68, '开': 69, '队': 70, '公': 71, '动': 72, '同': 73, '分': 74, '后': 75, '就': 76, '法': 77, '美': 78, '产': 79, '场': 80, '高': 81, '力': 82, '能': 83, '自': 84, '说': 85, '与': 86, '重': 87, '前': 88, '关': 89, '者': 90, '月': 91, '加': 92, '用': 93, '员': 94, '过': 95, '合': 96, '6': 97, '天': 98, '济': 99, '报': 100, '建': 101, '化': 102, '小': 103, '而': 104, '也': 105, '等': 106, '得': 107, '4': 108, '面': 109, '将': 11
# ...
